# %%
pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 4.3 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable-baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable-baselines3-2.2.1

# %%
pip install shimmy>=0.2.1

# %%
import random

import gym
import numpy as np


class GridWorld(gym.Env):
    def __init__(self, env_flag=2, append_context=False, continuous_action=True):
        super(gym.Env).__init__()
        self.deterministic = True
        # A, B, C, s_0, D
        # ------------------------
        # |    A, B, C   | None  |
        # ------------------------
        # |      s_0     |  D    |
        # ------------------------
        # 0 stay
        # 1 up
        # 2 right
        # 3 left
        # 4 down
        self.continuous_action = continuous_action
        if self.continuous_action:
            self.action_space = gym.spaces.Box(low=-1, high=1, shape=(1,))
        else:
            self.action_space = gym.spaces.Discrete(5)

        self.observation_space = None
        self._grid_escape_time = 0
        self._grid_max_time = 1000
        self._current_position = 0
        self.env_flag = env_flag
        self.append_context = append_context
        self.middle_state = [2, 3, 4]
        assert self.env_flag in self.middle_state, '{} is accepted.'.format(self.middle_state)
        self._ind_to_name = {
            0: 's0',
            1: 'D',
            2: 'A',
            3: 'B',
            4: 'C',
            5: 'None'
        }
        self.reward_setting = {
            0: 0,
            1: 1,
            2: 10,
            3: -10,
            4: 0,
            5: 0
        }
        for k in self.reward_setting:
            self.reward_setting[k] *= 0.1

        self.state_space = len(self.reward_setting)
        self._raw_state_length = self.state_space
        if self.append_context:
            self.state_space += len(self.middle_state)
        self.diy_env = True
        self.observation_space = gym.spaces.Box(0, 1, (self.state_space, ))

    @property
    def middle_state_embedding(self):
        v = [0] * len(self.middle_state)
        v[self.env_flag - 2] = 1
        return v

    def make_one_hot(self, state):
        vec = [0] * self._raw_state_length
        vec[state] = 1
        return vec

    def get_next_position_toy(self, action):
        if self._current_position == 0:
            if action == 0:
                # to D
                next_state = 1
            else:
                # to unknown position
                next_state = self.env_flag
        # elif self._current_position == 1:
        #     # keep at D
        #     next_state = 1
        elif self._current_position in self.middle_state + [1]:
            # to s0
            next_state = 0
        else:
            raise NotImplementedError('current position exceeds range!!!')
        return next_state

    def get_next_position(self, action):
        # ------------------------
        # |    A, B, C   | None  |
        # ------------------------
        # |      s_0     |  D    |
        # ------------------------
        # action: 0 stay
        # action: 1 up
        # action: 2 right
        # action: 3 left
        # action: 4 down
        # self._ind_to_name = {
        #             0: 's0',
        #             1: 'D',
        #             2: 'A',
        #             3: 'B',
        #             4: 'C',
        #             5: 'None'
        #         }
        if not self.deterministic:
            if random.random() > 0.5:
                action = action
            else:
                action = random.randint(0, 4)
        if action == 0:
            if self._current_position in [2, 3, 4]:
                return self.env_flag
            return self._current_position
        left_up_map = {
            4: 0,
            # 2: 5
        }
        action_transition_mapping = \
        {
            0: {1: self.env_flag, 2: 1},
            1: {1: 5, 3: 0},
            5: {3: self.env_flag, 4:1},
            2: left_up_map,
            3: left_up_map,
            4: left_up_map
        }
        action_to_state = action_transition_mapping[self._current_position]
        if action in action_to_state:
            return action_to_state[action]
        if self._current_position in [2, 3, 4]:
            return self.env_flag
        return self._current_position

    def step(self, action):
        self._grid_escape_time += 1
        info = {}
        if self.continuous_action:
            action_tmp = (action[0] + 1) / 2
            action_tmp = int(action_tmp * 5)
            if action_tmp >= 5:
                action_tmp = 4
            next_state = self.get_next_position(action_tmp)
        else:
            assert isinstance(action, int), 'action should be int type rather than {}'.format(type(action))
            next_state = self.get_next_position(action)
        done = False # next_state == 1
        if self._grid_escape_time >= self._grid_max_time:
            done = True
        reward = self.reward_setting[next_state]
        info['current_position'] = self._ind_to_name[next_state]
        next_state_vector = self.make_one_hot(next_state)
        self._current_position = next_state
        if self.append_context:
            next_state_vector += self.middle_state_embedding
        return next_state_vector, reward, done, info

    def reset(self):
        self._grid_escape_time = 0
        self._current_position = 0
        state = self.make_one_hot(self._current_position)
        if self.append_context:
            state += self.middle_state_embedding
        return state

    def seed(self, seed=None):
        self.action_space.seed(seed)


class RandomGridWorld(GridWorld):
    def __init__(self, append_context=False):
        self.possible_choice = [2, 3, 4]
        self.renv_flag = random.choice(self.possible_choice)
        self.fix_env = None
        super(RandomGridWorld, self).__init__(self.renv_flag, append_context)

    def reset(self):
        if self.fix_env is None:
            self.renv_flag = random.choice(self.possible_choice)
            self.env_flag = self.renv_flag
        else:
            self.renv_flag = self.env_flag = self.fix_env
        return super(RandomGridWorld, self).reset()

    def set_fix_env(self, fix_env):
        self.renv_flag = self.env_flag = self.fix_env = fix_env

    def set_task(self, task):
        self.set_fix_env(task)

    def sample_tasks(self, n_tasks):
        if n_tasks < len(self.possible_choice):
            tasks = [random.choice(self.possible_choice) for _ in range(n_tasks)]
        else:
            tasks = []
            for i in range(n_tasks):
                tasks.append(self.possible_choice[i % len(self.possible_choice)])

        return tasks

    @property
    def env_parameter_vector_(self):
        return np.array([(self.renv_flag - np.min(self.possible_choice)) / (np.max(self.possible_choice)
                                                                            - np.min(self.possible_choice))])

    @property
    def env_parameter_length(self):
        return 1

from gym.envs.registration import register

register(
id='NSCartPoleV0', entry_point=RandomGridWorld
)

if __name__ == '__main__':
    import gym
    env = gym.make('NSCartPoleV0')
    print('observation space: ', env.observation_space)
    print('action space: ', env.action_space)
    print(hasattr(env, 'rmdm_env_flag'))
# Out:
# observation space:  Box(0.0, 1.0, (6,), float32)
# action space:  Box(-1.0, 1.0, (1,), float32)
# False
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
import random
import gym
import matplotlib.pyplot as plt
from stable_baselines3 import SAC
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv

# Define the environment creation function
def create_env():
    return RandomGridWorld(append_context=True)

# Create the environment
env = DummyVecEnv([create_env])

# Define and create the SAC model
model = SAC("MlpPolicy", env, verbose=1)

# Training parameters
total_timesteps = 200000

# Train the model
model.learn(total_timesteps=total_timesteps)

# Evaluate the trained model
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean Reward: {mean_reward:.2f}")

# Save the model
model.save("sac_random_gridworld")

# Load the model
# loaded_model = SAC.load("sac_random_gridworld")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 79       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.0462   |
# |    ent_coef        | 0.33     |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 81       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 0.0303   |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -2.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 81       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 0.0197   |
# |    ent_coef        | 0.0343   |
# |    ent_coef_loss   | -2.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 82       |
# |    time_elapsed    | 194      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -21.5    |
# |    critic_loss     | 0.0121   |
# |    ent_coef        | 0.0163   |
# |    ent_coef_loss   | 0.595    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 82       |
# |    time_elapsed    | 242      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -21      |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.0145   |
# |    ent_coef_loss   | 0.574    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 82       |
# |    time_elapsed    | 290      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 0.156    |
# |    ent_coef        | 0.0172   |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 82       |
# |    time_elapsed    | 339      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 0.101    |
# |    ent_coef        | 0.0121   |
# |    ent_coef_loss   | 1.21     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 82       |
# |    time_elapsed    | 387      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 0.0072   |
# |    ent_coef        | 0.0174   |
# |    ent_coef_loss   | 0.363    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 82       |
# |    time_elapsed    | 435      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -27.2    |
# |    critic_loss     | 23.6     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | 0.168    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 82       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 0.407    |
# |    ent_coef        | 0.0141   |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 82       |
# |    time_elapsed    | 530      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 0.00353  |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | 0.619    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 82       |
# |    time_elapsed    | 578      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 0.00837  |
# |    ent_coef        | 0.0132   |
# |    ent_coef_loss   | 0.791    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 82       |
# |    time_elapsed    | 626      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -25.9    |
# |    critic_loss     | 0.0169   |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | -0.821   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 82       |
# |    time_elapsed    | 674      |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -28.4    |
# |    critic_loss     | 29.1     |
# |    ent_coef        | 0.0104   |
# |    ent_coef_loss   | 1.65     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 83       |
# |    time_elapsed    | 721      |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -25.9    |
# |    critic_loss     | 0.0102   |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 83       |
# |    time_elapsed    | 770      |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 0.229    |
# |    ent_coef        | 0.0108   |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 83       |
# |    time_elapsed    | 817      |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 0.169    |
# |    ent_coef        | 0.0135   |
# |    ent_coef_loss   | -0.044   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 83       |
# |    time_elapsed    | 865      |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -26.5    |
# |    critic_loss     | 0.0497   |
# |    ent_coef        | 0.0124   |
# |    ent_coef_loss   | 0.749    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 83       |
# |    time_elapsed    | 913      |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -29.8    |
# |    critic_loss     | 0.397    |
# |    ent_coef        | 0.0181   |
# |    ent_coef_loss   | -0.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 83       |
# |    time_elapsed    | 961      |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 0.00985  |
# |    ent_coef        | 0.0154   |
# |    ent_coef_loss   | -0.0874  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 83       |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -29.4    |
# |    critic_loss     | 0.203    |
# |    ent_coef        | 0.0102   |
# |    ent_coef_loss   | 0.364    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 83       |
# |    time_elapsed    | 1056     |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -25.2    |
# |    critic_loss     | 0.00857  |
# |    ent_coef        | 0.014    |
# |    ent_coef_loss   | -0.0873  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 83       |
# |    time_elapsed    | 1104     |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -28.1    |
# |    critic_loss     | 0.0474   |
# |    ent_coef        | 0.0133   |
# |    ent_coef_loss   | 0.0568   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 83       |
# |    time_elapsed    | 1151     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 0.0247   |
# |    ent_coef        | 0.0145   |
# |    ent_coef_loss   | -0.875   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 83       |
# |    time_elapsed    | 1199     |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 0.036    |
# |    ent_coef        | 0.0125   |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99899    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 83       |
# |    time_elapsed    | 1246     |
# |    total_timesteps | 104000   |
# | train/             |          |
# |    actor_loss      | -27.1    |
# |    critic_loss     | 0.0219   |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -0.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 103899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 83       |
# |    time_elapsed    | 1294     |
# |    total_timesteps | 108000   |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 0.0081   |
# |    ent_coef        | 0.0138   |
# |    ent_coef_loss   | -0.157   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 83       |
# |    time_elapsed    | 1342     |
# |    total_timesteps | 112000   |
# | train/             |          |
# |    actor_loss      | -27.2    |
# |    critic_loss     | 0.00482  |
# |    ent_coef        | 0.0103   |
# |    ent_coef_loss   | -0.645   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 83       |
# |    time_elapsed    | 1390     |
# |    total_timesteps | 116000   |
# | train/             |          |
# |    actor_loss      | -28.1    |
# |    critic_loss     | 0.0745   |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -0.0384  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 115899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 83       |
# |    time_elapsed    | 1437     |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 0.00361  |
# |    ent_coef        | 0.00991  |
# |    ent_coef_loss   | -0.0435  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 83       |
# |    time_elapsed    | 1485     |
# |    total_timesteps | 124000   |
# | train/             |          |
# |    actor_loss      | -30.3    |
# |    critic_loss     | 0.056    |
# |    ent_coef        | 0.0113   |
# |    ent_coef_loss   | -0.254   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 123899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 83       |
# |    time_elapsed    | 1532     |
# |    total_timesteps | 128000   |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 0.00266  |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -0.425   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 127899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 83       |
# |    time_elapsed    | 1580     |
# |    total_timesteps | 132000   |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 0.209    |
# |    ent_coef        | 0.0151   |
# |    ent_coef_loss   | 0.519    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 131899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 83       |
# |    time_elapsed    | 1627     |
# |    total_timesteps | 136000   |
# | train/             |          |
# |    actor_loss      | -30.8    |
# |    critic_loss     | 0.0894   |
# |    ent_coef        | 0.00946  |
# |    ent_coef_loss   | -0.191   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 135899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 83       |
# |    time_elapsed    | 1674     |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | -28      |
# |    critic_loss     | 0.00429  |
# |    ent_coef        | 0.0126   |
# |    ent_coef_loss   | -0.56    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 139899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 83       |
# |    time_elapsed    | 1720     |
# |    total_timesteps | 144000   |
# | train/             |          |
# |    actor_loss      | -26.3    |
# |    critic_loss     | 31.9     |
# |    ent_coef        | 0.0114   |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 143899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 83       |
# |    time_elapsed    | 1766     |
# |    total_timesteps | 148000   |
# | train/             |          |
# |    actor_loss      | -27.8    |
# |    critic_loss     | 0.2      |
# |    ent_coef        | 0.0109   |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 147899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 83       |
# |    time_elapsed    | 1812     |
# |    total_timesteps | 152000   |
# | train/             |          |
# |    actor_loss      | -32.3    |
# |    critic_loss     | 0.196    |
# |    ent_coef        | 0.0104   |
# |    ent_coef_loss   | 0.719    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 151899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 83       |
# |    time_elapsed    | 1858     |
# |    total_timesteps | 156000   |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 0.136    |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | 0.0333   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 155899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 83       |
# |    time_elapsed    | 1905     |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | -28.7    |
# |    critic_loss     | 0.0105   |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | 0.17     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 159899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 83       |
# |    time_elapsed    | 1952     |
# |    total_timesteps | 164000   |
# | train/             |          |
# |    actor_loss      | -30.6    |
# |    critic_loss     | 0.00344  |
# |    ent_coef        | 0.0115   |
# |    ent_coef_loss   | -2.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 163899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 83       |
# |    time_elapsed    | 2000     |
# |    total_timesteps | 168000   |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 0.0329   |
# |    ent_coef        | 0.0126   |
# |    ent_coef_loss   | -0.518   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 167899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 83       |
# |    time_elapsed    | 2048     |
# |    total_timesteps | 172000   |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 0.0777   |
# |    ent_coef        | 0.0118   |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 171899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 83       |
# |    time_elapsed    | 2096     |
# |    total_timesteps | 176000   |
# | train/             |          |
# |    actor_loss      | -31.6    |
# |    critic_loss     | 31.4     |
# |    ent_coef        | 0.0126   |
# |    ent_coef_loss   | 0.826    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 83       |
# |    time_elapsed    | 2143     |
# |    total_timesteps | 180000   |
# | train/             |          |
# |    actor_loss      | -27.8    |
# |    critic_loss     | 0.00134  |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -0.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 83       |
# |    time_elapsed    | 2191     |
# |    total_timesteps | 184000   |
# | train/             |          |
# |    actor_loss      | -31.7    |
# |    critic_loss     | 0.00326  |
# |    ent_coef        | 0.0126   |
# |    ent_coef_loss   | 0.669    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 183899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 83       |
# |    time_elapsed    | 2238     |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -28.1    |
# |    critic_loss     | 0.00402  |
# |    ent_coef        | 0.00998  |
# |    ent_coef_loss   | 2.55     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 84       |
# |    time_elapsed    | 2285     |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -29.5    |
# |    critic_loss     | 0.00167  |
# |    ent_coef        | 0.0157   |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 191899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 83       |
# |    time_elapsed    | 2334     |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 0.0135   |
# |    ent_coef        | 0.0124   |
# |    ent_coef_loss   | -0.345   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 195899   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 83       |
# |    time_elapsed    | 2382     |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 0.249    |
# |    ent_coef        | 0.0163   |
# |    ent_coef_loss   | 0.649    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 199899   |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean Reward: 460.00

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# Number of data points in the learning curve
num_points = 500

# Initialize an empty learning curve with random data
learning_curve = np.random.rand(num_points)

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Initialize the plot with two empty curves (original in blue, smoothed in green)
line1, = ax.plot([], [], lw=2, color='red', label='Original Reward')
line2, = ax.plot([], [], lw=2, color='green', label='Smoothed Reward')
ax.set_xlim(0, num_points)
ax.set_ylim(0, 1)
ax.legend()  # Add a legend

# Define the window size for the moving average
window_size = 10

# Update function to simulate changes in the learning curve and apply smoothing
def update(frame):
    if frame < num_points:
        # Simulate changes in the learning curve with random data
        learning_curve[frame:] += np.random.uniform(-0.1, 0.1)
        # Apply a simple moving average to smooth the curve
        smoothed_curve = np.convolve(learning_curve, np.ones(window_size)/window_size, mode='valid')
        line1.set_data(range(num_points), learning_curve)
        line2.set_data(range(len(smoothed_curve)), smoothed_curve)
        return line1, line2  # Return both lines

# Create the animation
ani = FuncAnimation(fig, update, frames=num_points, repeat=False, blit=True)

# Display the dynamic learning curves
plt.xlabel("Time")
plt.ylabel("Reward")
plt.title("Dynamic Reward and Smoothed Reward")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class ActorNetwork(nn.Module):
    def __init__(self, input_dims, n_actions, max_action):
        super(ActorNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dims, 256)
        self.fc2 = nn.Linear(256, 256)
        self.mu = nn.Linear(256, n_actions)
        self.sigma = nn.Linear(256, n_actions)
        self.max_action = max_action

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        mu = self.mu(x)
        sigma = self.sigma(x)
        sigma = torch.clamp(sigma, min=-20, max=2)
        return mu, sigma

    def sample_normal(self, state, reparameterize=True):
        mu, sigma = self.forward(state)
        sigma = sigma.exp()
        probabilities = torch.distributions.Normal(mu, sigma)
        if reparameterize:
            actions = probabilities.rsample()
        else:
            actions = probabilities.sample()
        action = torch.tanh(actions) * self.max_action
        log_probs = probabilities.log_prob(actions)
        log_probs -= torch.log(1 - action.pow(2) + 1e-6)
        log_probs = log_probs.sum(1, keepdim=True)
        return action, log_probs

class CriticNetwork(nn.Module):
    def __init__(self, input_dims, n_actions):
        super(CriticNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dims + n_actions, 256)
        self.fc2 = nn.Linear(256, 256)
        self.q = nn.Linear(256, 1)

    def forward(self, state, action):
        q_input = torch.cat([state, action], 1)
        x = F.relu(self.fc1(q_input))
        x = F.relu(self.fc2(x))
        q_value = self.q(x)
        return q_value

class ReplayBuffer:
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1 - done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones

    def store_transition(self, state, action, reward, next_state, done):
        # Your code to store the transition in the buffer
        pass

# ... rest of your class definition ...

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

class ReplayBuffer:
    def __init__(self, mem_size, input_shape, n_actions):
        self.mem_size = mem_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1 - done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones

class CriticNetwork(nn.Module):
    def __init__(self, input_dims, n_actions):
        super(CriticNetwork, self).__init__()
        self.fc1 = nn.Linear(*input_dims + n_actions, 256)
        self.fc2 = nn.Linear(256, 256)
        self.q = nn.Linear(256, 1)

    def forward(self, state, action):
        q1_action_value = self.fc1(torch.cat([state, action], dim=1))
        q1_action_value = nn.ReLU()(q1_action_value)
        q1_action_value = self.fc2(q1_action_value)
        q1_action_value = nn.ReLU()(q1_action_value)
        q1 = self.q(q1_action_value)

        return q1

class ActorNetwork(nn.Module):
    def __init__(self, input_dims, n_actions):
        super(ActorNetwork, self).__init__()
        self.fc1 = nn.Linear(*input_dims, 256)
        self.fc2 = nn.Linear(256, 256)
        self.mu = nn.Linear(256, n_actions)

    def forward(self, state):
        prob = self.fc1(state)
        prob = nn.ReLU()(prob)
        prob = self.fc2(prob)
        prob = nn.ReLU()(prob)
        mu = self.mu(prob)

        return mu

class ESCPAgent:
    def __init__(self, input_dims, n_actions, lr, gamma, tau, alpha, batch_size, mem_size, max_action):
        self.gamma = gamma
        self.tau = tau
        self.alpha = alpha
        self.batch_size = batch_size
        self.memory = ReplayBuffer(mem_size, input_shape=input_dims, n_actions=n_actions)
        self.max_action = max_action

        self.actor = ActorNetwork(input_dims=input_dims, n_actions=n_actions)
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=lr)

        self.critic_1 = CriticNetwork(input_dims=input_dims, n_actions=n_actions)
        self.critic_2 = CriticNetwork(input_dims=input_dims, n_actions=n_actions)
        self.critic_1_optimizer = optim.Adam(self.critic_1.parameters(), lr=lr)
        self.critic_2_optimizer = optim.Adam(self.critic_2.parameters(), lr=lr)

        self.target_critic_1 = CriticNetwork(input_dims=input_dims, n_actions=n_actions)
        self.target_critic_2 = CriticNetwork(input_dims=input_dims, n_actions=n_actions)

        self.update_network_parameters(tau=1)





    def choose_action(self, observation):
        self.actor.eval()  # Set the network to evaluation mode
        state = torch.tensor([observation], dtype=torch.float32)
        actions = self.actor(state).cpu().detach().numpy()[0]
        self.actor.train()  # Set the network back to train mode
        return np.clip(actions, -self.max_action, self.max_action)  # Clip actions to be within the action space

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        # Update the target network parameters slowly
        # based on the current network parameters and tau
        # ...

    def learn(self):
        # Ensure that we have enough samples in the replay buffer
        if self.memory.mem_cntr < self.batch_size:
            return

        # Sample a batch of experiences from the replay buffer
        # Perform learning step
        # ...


    def store_transition(self, state, action, reward, next_state, done):
        self.memory.store_transition(state, action, reward, next_state, done)

# %%
import gym
from gym import spaces
import numpy as np

class NSCartPoleV0(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self):
        super(NSCartPoleV0, self).__init__()

        # Define a continuous action space where the magnitude of the force can be between -10 and 10
        self.action_space = spaces.Box(low=-10.0, high=10.0, shape=(1,), dtype=np.float32)

        # Define the observation space with the physics limits of the system
        high = np.array([
            np.finfo(np.float32).max,  # cart position, no limit
            np.finfo(np.float32).max,  # cart velocity
            np.pi,                     # pole angle from vertical
            np.finfo(np.float32).max   # pole velocity at tip
        ], dtype=np.float32)

        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        # Physical system parameters
        self.gravity = 9.8
        self.masscart = 1.0
        self.masspole = 0.1
        self.total_mass = (self.masspole + self.masscart)
        self.length = 0.5  # actually half the pole's length
        self.polemass_length = (self.masspole * self.length)
        self.force_mag = 10.0
        self.tau = 0.02  # seconds between state updates

        # Angle at which to fail the episode
        self.theta_threshold_radians = 12 * 2 * np.pi / 360
        self.x_threshold = 2.4

        # Initialize state variables
        self.state = None
        self.steps_beyond_done = None

    def step(self, action):
        err_msg = "%r (%s) invalid" % (action, type(action))
        assert self.action_space.contains(action), err_msg

        state = self.state
        x, x_dot, theta, theta_dot = state
        force = action[0]

        # Physics for updating the state
        costheta = np.cos(theta)
        sintheta = np.sin(theta)

        # For the inverted pendulum dynamics refer to: http://coneural.org/florian/papers/05_cart_pole.pdf
        temp = (force + self.polemass_length * theta_dot ** 2 * sintheta) / self.total_mass
        thetaacc = (self.gravity * sintheta - costheta * temp) / (self.length * (4.0/3.0 - self.masspole * costheta ** 2 / self.total_mass))
        xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass

        # Update the four state variables, using Euler's method for simplicity
        x = x + self.tau * x_dot
        x_dot = x_dot + self.tau * xacc
        theta = theta + self.tau * theta_dot
        theta_dot = theta_dot + self.tau * thetaacc

        self.state = (x, x_dot, theta, theta_dot)

        done = x < -self.x_threshold \
               or x > self.x_threshold \
               or theta < -self.theta_threshold_radians \
               or theta > self.theta_threshold_radians
        done = bool(done)

        if not done:
            reward = 1.0
        elif self.steps_beyond_done is None:
            # Pole just fell!
            self.steps_beyond_done = 0
            reward = 1.0
        else:
            if self.steps_beyond_done == 0:
                print("You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.")
            self.steps_beyond_done += 1
            reward = 0.0

        return np.array(self.state), reward, done, {}

    def reset(self):
        self.state = self.np_random.uniform(low=-0.05, high=0.05, size=(4,))
        self.steps_beyond_done = None
        return np.array(self.state)

    def render(self, mode='human', close=False):
        # Implement this method if you want to do rendering
        pass

    def close(self):
        # Implement this method for any cleanup when closing the environment
        pass
    def reset(self):
      self.state = self.np_random.uniform(low=-0.05, high=0.05, size=(4,))
      self.steps_beyond_done = None

    # Change gravity each episode to introduce non-stationarity
      self.gravity = np.random.uniform(9.0, 10.0)

      return np.array(self.state)

# %%
import gym
import numpy as np

class NonStationaryWrapper(gym.Wrapper):
    def __init__(self, env, gravity_range=(9.0, 10.0), change_every_n_episodes=10):
        super(NonStationaryWrapper, self).__init__(env)
        self.gravity_range = gravity_range
        self.change_every_n_episodes = change_every_n_episodes
        self.episode_count = 0

    def reset(self, **kwargs):
        # Change gravity every `change_every_n_episodes` episodes
        if self.episode_count % self.change_every_n_episodes == 0:
            new_gravity = np.random.uniform(*self.gravity_range)
            self.env.gravity = new_gravity
            print(f"Changing environment gravity to {new_gravity}")

        self.episode_count += 1
        return self.env.reset(**kwargs)

# %%
class CriticNetwork(nn.Module):
    def __init__(self, input_dims, n_actions):
        super(CriticNetwork, self).__init__()
        # Combine the input dimensions and number of actions correctly
        self.fc1 = nn.Linear(input_dims[0] + n_actions, 256)
        self.fc2 = nn.Linear(256, 256)
        self.q = nn.Linear(256, 1)

# %%
import matplotlib.pyplot as plt

def train_agent(env, agent, n_episodes=100):
    all_rewards = []

    for episode in range(n_episodes):
        obs = env.reset()
        done = False
        episode_reward = 0

        while not done:
            action = agent.choose_action(obs)
            new_obs, reward, done, _ = env.step(action)

            agent.store_transition(obs, action, reward, new_obs, done)
            agent.learn()

            obs = new_obs
            episode_reward += reward

        all_rewards.append(episode_reward)
        print(f"Episode {episode + 1}: Reward = {episode_reward}")

    return all_rewards

if __name__ == '__main__':
    env = NSCartPoleV0()  # Ensure NSCartPoleV0 is defined properly with continuous action space
    input_dims = env.observation_space.shape[0]
    n_actions = env.action_space.shape[0]
    max_action = env.action_space.high[0]  # Assuming symmetric action space

    agent = ESCPAgent(input_dims=[input_dims], n_actions=n_actions, lr=0.001, gamma=0.99,
                      tau=0.005, alpha=0.2, batch_size=64, mem_size=1000000, max_action=max_action)

    n_episodes = 500
    all_rewards = train_agent(env, agent, n_episodes)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(all_rewards, label='Original Reward')

    smoothed_rewards = [np.mean(all_rewards[max(0, i-10):i+1]) for i in range(len(all_rewards))]
    plt.plot(smoothed_rewards, color='orange', label='Smoothed Reward')

    plt.xlabel('Time')
    plt.ylabel('Reward')
    plt.title("Dynamic Reward and Smoothed Reward")
    plt.legend()
    plt.show()
# Out:
# <ipython-input-7-e6c061b710a9>:97: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   state = torch.tensor([observation], dtype=torch.float32)
# Episode 1: Reward = 29.0
# Episode 2: Reward = 37.0
# Episode 3: Reward = 34.0
# Episode 4: Reward = 34.0
# Episode 5: Reward = 36.0
# Episode 6: Reward = 52.0
# Episode 7: Reward = 40.0
# Episode 8: Reward = 36.0
# Episode 9: Reward = 35.0
# Episode 10: Reward = 54.0
# Episode 11: Reward = 56.0
# Episode 12: Reward = 35.0
# Episode 13: Reward = 73.0
# Episode 14: Reward = 42.0
# Episode 15: Reward = 32.0
# Episode 16: Reward = 33.0
# Episode 17: Reward = 36.0
# Episode 18: Reward = 33.0
# Episode 19: Reward = 41.0
# Episode 20: Reward = 36.0
# Episode 21: Reward = 48.0
# Episode 22: Reward = 36.0
# Episode 23: Reward = 46.0
# Episode 24: Reward = 34.0
# Episode 25: Reward = 31.0
# Episode 26: Reward = 32.0
# Episode 27: Reward = 31.0
# Episode 28: Reward = 41.0
# Episode 29: Reward = 33.0
# Episode 30: Reward = 41.0
# Episode 31: Reward = 33.0
# Episode 32: Reward = 40.0
# Episode 33: Reward = 35.0
# Episode 34: Reward = 56.0
# Episode 35: Reward = 73.0
# Episode 36: Reward = 29.0
# Episode 37: Reward = 31.0
# Episode 38: Reward = 29.0
# Episode 39: Reward = 32.0
# Episode 40: Reward = 49.0
# Episode 41: Reward = 64.0
# Episode 42: Reward = 33.0
# Episode 43: Reward = 35.0
# Episode 44: Reward = 32.0
# Episode 45: Reward = 31.0
# Episode 46: Reward = 36.0
# Episode 47: Reward = 33.0
# Episode 48: Reward = 33.0
# Episode 49: Reward = 30.0
# Episode 50: Reward = 34.0
# Episode 51: Reward = 37.0
# Episode 52: Reward = 36.0
# Episode 53: Reward = 37.0
# Episode 54: Reward = 32.0
# Episode 55: Reward = 28.0
# Episode 56: Reward = 36.0
# Episode 57: Reward = 73.0
# Episode 58: Reward = 30.0
# Episode 59: Reward = 42.0
# Episode 60: Reward = 31.0
# Episode 61: Reward = 53.0
# Episode 62: Reward = 52.0
# Episode 63: Reward = 46.0
# Episode 64: Reward = 26.0
# Episode 65: Reward = 30.0
# Episode 66: Reward = 53.0
# Episode 67: Reward = 56.0
# Episode 68: Reward = 31.0
# Episode 69: Reward = 37.0
# Episode 70: Reward = 30.0
# Episode 71: Reward = 32.0
# Episode 72: Reward = 34.0
# Episode 73: Reward = 40.0
# Episode 74: Reward = 37.0
# Episode 75: Reward = 41.0
# Episode 76: Reward = 37.0
# Episode 77: Reward = 46.0
# Episode 78: Reward = 46.0
# Episode 79: Reward = 42.0
# Episode 80: Reward = 56.0
# Episode 81: Reward = 73.0
# Episode 82: Reward = 39.0
# Episode 83: Reward = 67.0
# Episode 84: Reward = 33.0
# Episode 85: Reward = 42.0
# Episode 86: Reward = 63.0
# Episode 87: Reward = 35.0
# Episode 88: Reward = 76.0
# Episode 89: Reward = 44.0
# Episode 90: Reward = 50.0
# Episode 91: Reward = 49.0
# Episode 92: Reward = 47.0
# Episode 93: Reward = 34.0
# Episode 94: Reward = 48.0
# Episode 95: Reward = 63.0
# Episode 96: Reward = 43.0
# Episode 97: Reward = 44.0
# Episode 98: Reward = 33.0
# Episode 99: Reward = 34.0
# Episode 100: Reward = 71.0
# Episode 101: Reward = 37.0
# Episode 102: Reward = 35.0
# Episode 103: Reward = 33.0
# Episode 104: Reward = 35.0
# Episode 105: Reward = 36.0
# Episode 106: Reward = 38.0
# Episode 107: Reward = 39.0
# Episode 108: Reward = 41.0
# Episode 109: Reward = 30.0
# Episode 110: Reward = 31.0
# Episode 111: Reward = 30.0
# Episode 112: Reward = 40.0
# Episode 113: Reward = 37.0
# Episode 114: Reward = 37.0
# Episode 115: Reward = 35.0
# Episode 116: Reward = 47.0
# Episode 117: Reward = 41.0
# Episode 118: Reward = 40.0
# Episode 119: Reward = 44.0
# Episode 120: Reward = 55.0
# Episode 121: Reward = 65.0
# Episode 122: Reward = 38.0
# Episode 123: Reward = 44.0
# Episode 124: Reward = 35.0
# Episode 125: Reward = 35.0
# Episode 126: Reward = 31.0
# Episode 127: Reward = 33.0
# Episode 128: Reward = 59.0
# Episode 129: Reward = 38.0
# Episode 130: Reward = 46.0
# Episode 131: Reward = 34.0
# Episode 132: Reward = 29.0
# Episode 133: Reward = 38.0
# Episode 134: Reward = 36.0
# Episode 135: Reward = 28.0
# Episode 136: Reward = 34.0
# Episode 137: Reward = 49.0
# Episode 138: Reward = 62.0
# Episode 139: Reward = 36.0
# Episode 140: Reward = 40.0
# Episode 141: Reward = 37.0
# Episode 142: Reward = 37.0
# Episode 143: Reward = 53.0
# Episode 144: Reward = 37.0
# Episode 145: Reward = 44.0
# Episode 146: Reward = 41.0
# Episode 147: Reward = 36.0
# Episode 148: Reward = 50.0
# Episode 149: Reward = 53.0
# Episode 150: Reward = 30.0
# Episode 151: Reward = 46.0
# Episode 152: Reward = 30.0
# Episode 153: Reward = 31.0
# Episode 154: Reward = 30.0
# Episode 155: Reward = 30.0
# Episode 156: Reward = 127.0
# Episode 157: Reward = 38.0
# Episode 158: Reward = 34.0
# Episode 159: Reward = 31.0
# Episode 160: Reward = 36.0
# Episode 161: Reward = 32.0
# Episode 162: Reward = 39.0
# Episode 163: Reward = 49.0
# Episode 164: Reward = 38.0
# Episode 165: Reward = 30.0
# Episode 166: Reward = 34.0
# Episode 167: Reward = 39.0
# Episode 168: Reward = 49.0
# Episode 169: Reward = 37.0
# Episode 170: Reward = 29.0
# Episode 171: Reward = 37.0
# Episode 172: Reward = 29.0
# Episode 173: Reward = 48.0
# Episode 174: Reward = 39.0
# Episode 175: Reward = 46.0
# Episode 176: Reward = 32.0
# Episode 177: Reward = 72.0
# Episode 178: Reward = 43.0
# Episode 179: Reward = 46.0
# Episode 180: Reward = 29.0
# Episode 181: Reward = 52.0
# Episode 182: Reward = 72.0
# Episode 183: Reward = 39.0
# Episode 184: Reward = 32.0
# Episode 185: Reward = 51.0
# Episode 186: Reward = 42.0
# Episode 187: Reward = 42.0
# Episode 188: Reward = 54.0
# Episode 189: Reward = 37.0
# Episode 190: Reward = 32.0
# Episode 191: Reward = 41.0
# Episode 192: Reward = 35.0
# Episode 193: Reward = 39.0
# Episode 194: Reward = 28.0
# Episode 195: Reward = 32.0
# Episode 196: Reward = 39.0
# Episode 197: Reward = 52.0
# Episode 198: Reward = 71.0
# Episode 199: Reward = 38.0
# Episode 200: Reward = 50.0
# Episode 201: Reward = 31.0
# Episode 202: Reward = 33.0
# Episode 203: Reward = 32.0
# Episode 204: Reward = 46.0
# Episode 205: Reward = 31.0
# Episode 206: Reward = 42.0
# Episode 207: Reward = 31.0
# Episode 208: Reward = 48.0
# Episode 209: Reward = 45.0
# Episode 210: Reward = 33.0
# Episode 211: Reward = 31.0
# Episode 212: Reward = 37.0
# Episode 213: Reward = 37.0
# Episode 214: Reward = 44.0
# Episode 215: Reward = 66.0
# Episode 216: Reward = 33.0
# Episode 217: Reward = 49.0
# Episode 218: Reward = 45.0
# Episode 219: Reward = 35.0
# Episode 220: Reward = 51.0
# Episode 221: Reward = 37.0
# Episode 222: Reward = 50.0
# Episode 223: Reward = 35.0
# Episode 224: Reward = 33.0
# Episode 225: Reward = 37.0
# Episode 226: Reward = 44.0
# Episode 227: Reward = 46.0
# Episode 228: Reward = 31.0
# Episode 229: Reward = 36.0
# Episode 230: Reward = 32.0
# Episode 231: Reward = 29.0
# Episode 232: Reward = 31.0
# Episode 233: Reward = 35.0
# Episode 234: Reward = 33.0
# Episode 235: Reward = 36.0
# Episode 236: Reward = 31.0
# Episode 237: Reward = 40.0
# Episode 238: Reward = 36.0
# Episode 239: Reward = 38.0
# Episode 240: Reward = 46.0
# Episode 241: Reward = 35.0
# Episode 242: Reward = 25.0
# Episode 243: Reward = 29.0
# Episode 244: Reward = 30.0
# Episode 245: Reward = 61.0
# Episode 246: Reward = 53.0
# Episode 247: Reward = 38.0
# Episode 248: Reward = 54.0
# Episode 249: Reward = 25.0
# Episode 250: Reward = 36.0
# Episode 251: Reward = 59.0
# Episode 252: Reward = 45.0
# Episode 253: Reward = 41.0
# Episode 254: Reward = 35.0
# Episode 255: Reward = 43.0
# Episode 256: Reward = 28.0
# Episode 257: Reward = 47.0
# Episode 258: Reward = 67.0
# Episode 259: Reward = 39.0
# Episode 260: Reward = 54.0
# Episode 261: Reward = 41.0
# Episode 262: Reward = 44.0
# Episode 263: Reward = 55.0
# Episode 264: Reward = 31.0
# Episode 265: Reward = 29.0
# Episode 266: Reward = 38.0
# Episode 267: Reward = 34.0
# Episode 268: Reward = 31.0
# Episode 269: Reward = 51.0
# Episode 270: Reward = 40.0
# Episode 271: Reward = 48.0
# Episode 272: Reward = 40.0
# Episode 273: Reward = 29.0
# Episode 274: Reward = 47.0
# Episode 275: Reward = 28.0
# Episode 276: Reward = 42.0
# Episode 277: Reward = 45.0
# Episode 278: Reward = 37.0
# Episode 279: Reward = 28.0
# Episode 280: Reward = 37.0
# Episode 281: Reward = 46.0
# Episode 282: Reward = 44.0
# Episode 283: Reward = 51.0
# Episode 284: Reward = 35.0
# Episode 285: Reward = 36.0
# Episode 286: Reward = 32.0
# Episode 287: Reward = 29.0
# Episode 288: Reward = 35.0
# Episode 289: Reward = 31.0
# Episode 290: Reward = 62.0
# Episode 291: Reward = 46.0
# Episode 292: Reward = 36.0
# Episode 293: Reward = 30.0
# Episode 294: Reward = 56.0
# Episode 295: Reward = 33.0
# Episode 296: Reward = 40.0
# Episode 297: Reward = 37.0
# Episode 298: Reward = 51.0
# Episode 299: Reward = 42.0
# Episode 300: Reward = 34.0
# Episode 301: Reward = 49.0
# Episode 302: Reward = 30.0
# Episode 303: Reward = 51.0
# Episode 304: Reward = 43.0
# Episode 305: Reward = 48.0
# Episode 306: Reward = 36.0
# Episode 307: Reward = 64.0
# Episode 308: Reward = 36.0
# Episode 309: Reward = 46.0
# Episode 310: Reward = 34.0
# Episode 311: Reward = 51.0
# Episode 312: Reward = 38.0
# Episode 313: Reward = 37.0
# Episode 314: Reward = 49.0
# Episode 315: Reward = 36.0
# Episode 316: Reward = 30.0
# Episode 317: Reward = 28.0
# Episode 318: Reward = 33.0
# Episode 319: Reward = 76.0
# Episode 320: Reward = 52.0
# Episode 321: Reward = 35.0
# Episode 322: Reward = 65.0
# Episode 323: Reward = 30.0
# Episode 324: Reward = 44.0
# Episode 325: Reward = 41.0
# Episode 326: Reward = 52.0
# Episode 327: Reward = 29.0
# Episode 328: Reward = 33.0
# Episode 329: Reward = 30.0
# Episode 330: Reward = 55.0
# Episode 331: Reward = 40.0
# Episode 332: Reward = 49.0
# Episode 333: Reward = 56.0
# Episode 334: Reward = 36.0
# Episode 335: Reward = 33.0
# Episode 336: Reward = 41.0
# Episode 337: Reward = 28.0
# Episode 338: Reward = 35.0
# Episode 339: Reward = 27.0
# Episode 340: Reward = 29.0
# Episode 341: Reward = 29.0
# Episode 342: Reward = 35.0
# Episode 343: Reward = 30.0
# Episode 344: Reward = 36.0
# Episode 345: Reward = 56.0
# Episode 346: Reward = 48.0
# Episode 347: Reward = 31.0
# Episode 348: Reward = 38.0
# Episode 349: Reward = 30.0
# Episode 350: Reward = 29.0
# Episode 351: Reward = 32.0
# Episode 352: Reward = 37.0
# Episode 353: Reward = 36.0
# Episode 354: Reward = 38.0
# Episode 355: Reward = 33.0
# Episode 356: Reward = 41.0
# Episode 357: Reward = 28.0
# Episode 358: Reward = 47.0
# Episode 359: Reward = 48.0
# Episode 360: Reward = 35.0
# Episode 361: Reward = 63.0
# Episode 362: Reward = 33.0
# Episode 363: Reward = 37.0
# Episode 364: Reward = 35.0
# Episode 365: Reward = 37.0
# Episode 366: Reward = 29.0
# Episode 367: Reward = 29.0
# Episode 368: Reward = 38.0
# Episode 369: Reward = 52.0
# Episode 370: Reward = 52.0
# Episode 371: Reward = 31.0
# Episode 372: Reward = 33.0
# Episode 373: Reward = 32.0
# Episode 374: Reward = 31.0
# Episode 375: Reward = 33.0
# Episode 376: Reward = 46.0
# Episode 377: Reward = 63.0
# Episode 378: Reward = 33.0
# Episode 379: Reward = 51.0
# Episode 380: Reward = 64.0
# Episode 381: Reward = 37.0
# Episode 382: Reward = 42.0
# Episode 383: Reward = 36.0
# Episode 384: Reward = 33.0
# Episode 385: Reward = 64.0
# Episode 386: Reward = 34.0
# Episode 387: Reward = 33.0
# Episode 388: Reward = 36.0
# Episode 389: Reward = 61.0
# Episode 390: Reward = 40.0
# Episode 391: Reward = 32.0
# Episode 392: Reward = 80.0
# Episode 393: Reward = 35.0
# Episode 394: Reward = 63.0
# Episode 395: Reward = 36.0
# Episode 396: Reward = 40.0
# Episode 397: Reward = 37.0
# Episode 398: Reward = 57.0
# Episode 399: Reward = 29.0
# Episode 400: Reward = 27.0
# Episode 401: Reward = 32.0
# Episode 402: Reward = 37.0
# Episode 403: Reward = 32.0
# Episode 404: Reward = 34.0
# Episode 405: Reward = 37.0
# Episode 406: Reward = 35.0
# Episode 407: Reward = 38.0
# Episode 408: Reward = 31.0
# Episode 409: Reward = 31.0
# Episode 410: Reward = 37.0
# Episode 411: Reward = 49.0
# Episode 412: Reward = 60.0
# Episode 413: Reward = 52.0
# Episode 414: Reward = 35.0
# Episode 415: Reward = 35.0
# Episode 416: Reward = 34.0
# Episode 417: Reward = 36.0
# Episode 418: Reward = 41.0
# Episode 419: Reward = 37.0
# Episode 420: Reward = 37.0
# Episode 421: Reward = 39.0
# Episode 422: Reward = 36.0
# Episode 423: Reward = 58.0
# Episode 424: Reward = 35.0
# Episode 425: Reward = 46.0
# Episode 426: Reward = 43.0
# Episode 427: Reward = 32.0
# Episode 428: Reward = 32.0
# Episode 429: Reward = 29.0
# Episode 430: Reward = 43.0
# Episode 431: Reward = 37.0
# Episode 432: Reward = 65.0
# Episode 433: Reward = 40.0
# Episode 434: Reward = 32.0
# Episode 435: Reward = 34.0
# Episode 436: Reward = 39.0
# Episode 437: Reward = 54.0
# Episode 438: Reward = 73.0
# Episode 439: Reward = 64.0
# Episode 440: Reward = 44.0
# Episode 441: Reward = 27.0
# Episode 442: Reward = 50.0
# Episode 443: Reward = 39.0
# Episode 444: Reward = 45.0
# Episode 445: Reward = 32.0
# Episode 446: Reward = 34.0
# Episode 447: Reward = 42.0
# Episode 448: Reward = 33.0
# Episode 449: Reward = 31.0
# Episode 450: Reward = 42.0
# Episode 451: Reward = 31.0
# Episode 452: Reward = 61.0
# Episode 453: Reward = 72.0
# Episode 454: Reward = 42.0
# Episode 455: Reward = 41.0
# Episode 456: Reward = 39.0
# Episode 457: Reward = 39.0
# Episode 458: Reward = 49.0
# Episode 459: Reward = 61.0
# Episode 460: Reward = 33.0
# Episode 461: Reward = 36.0
# Episode 462: Reward = 44.0
# Episode 463: Reward = 43.0
# Episode 464: Reward = 31.0
# Episode 465: Reward = 33.0
# Episode 466: Reward = 138.0
# Episode 467: Reward = 49.0
# Episode 468: Reward = 41.0
# Episode 469: Reward = 30.0
# Episode 470: Reward = 38.0
# Episode 471: Reward = 26.0
# Episode 472: Reward = 29.0
# Episode 473: Reward = 71.0
# Episode 474: Reward = 48.0
# Episode 475: Reward = 54.0
# Episode 476: Reward = 36.0
# Episode 477: Reward = 35.0
# Episode 478: Reward = 29.0
# Episode 479: Reward = 44.0
# Episode 480: Reward = 35.0
# Episode 481: Reward = 33.0
# Episode 482: Reward = 40.0
# Episode 483: Reward = 46.0
# Episode 484: Reward = 73.0
# Episode 485: Reward = 63.0
# Episode 486: Reward = 37.0
# Episode 487: Reward = 40.0
# Episode 488: Reward = 33.0
# Episode 489: Reward = 31.0
# Episode 490: Reward = 34.0
# Episode 491: Reward = 38.0
# Episode 492: Reward = 43.0
# Episode 493: Reward = 34.0
# Episode 494: Reward = 37.0
# Episode 495: Reward = 39.0
# Episode 496: Reward = 42.0
# Episode 497: Reward = 63.0
# Episode 498: Reward = 34.0
# Episode 499: Reward = 71.0
# Episode 500: Reward = 59.0

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# ... (your training and agent setup code)

# Number of data points in the learning curve
num_points = 500

# Initialize an empty learning curve with random data
learning_curve = np.random.rand(num_points)

# Create a figure and axis for the plot
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), gridspec_kw={'height_ratios': [2, 1]})

# Plotting training rewards
ax1.plot(all_rewards, label='Reward per Episode')
smoothed_rewards = [np.mean(all_rewards[max(0, i-10):i+1]) for i in range(len(all_rewards))]
ax1.plot(smoothed_rewards, color='orange', label='Smoothed Training Reward')
ax1.set_xlabel('Episode')
ax1.set_ylabel('Reward')
ax1.set_title('Training Rewards over Episodes')
ax1.legend()

# Initialize the plot with two empty curves (original and smoothed dynamic curve)
line1, = ax2.plot([], [], lw=2, color='red', label='Dynamic Reward')
line2, = ax2.plot([], [], lw=2, color='green', label='Smoothed Dynamic Reward')
ax2.set_xlim(0, num_points)
ax2.set_ylim(0, 1)
ax2.legend()  # Add a legend

# Define the window size for the moving average
window_size = 10

# Update function to simulate changes in the learning curve and apply smoothing
def update(frame):
    if frame < num_points:
        # Simulate changes in the learning curve with random data
        learning_curve[frame:] += np.random.uniform(-0.1, 0.1)
        # Apply a simple moving average to smooth the curve
        smoothed_curve = np.convolve(learning_curve, np.ones(window_size)/window_size, mode='valid')
        line1.set_data(range(num_points), learning_curve)
        line2.set_data(range(len(smoothed_curve)), smoothed_curve)
        return line1, line2  # Return both lines

# Create the animation
ani = FuncAnimation(fig, update, frames=num_points, repeat=False, blit=True)

# Display the combined learning curves
ax2.set_xlabel("Time")
ax2.set_ylabel("Reward")
ax2.set_title("Dynamic Reward and Smoothed Dynamic Reward")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# Number of data points in the learning curve
num_points = 500

# Initialize an empty learning curve with random data
learning_curve = np.random.rand(num_points)

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Initialize the plot with two empty curves (original in blue, smoothed in green)
line1, = ax.plot([], [], lw=2, color='red', label='Original Reward')
line2, = ax.plot([], [], lw=2, color='green', label='Smoothed Reward')
ax.set_xlim(0, num_points)
ax.set_ylim(0, 1)
ax.legend()  # Add a legend

# Define the window size for the moving average
window_size = 10

# Update function to simulate changes in the learning curve and apply smoothing
def update(frame):
    if frame < num_points:
        # Simulate changes in the learning curve with random data
        learning_curve[frame:] += np.random.uniform(-0.1, 0.1)
        # Apply a simple moving average to smooth the curve
        smoothed_curve = np.convolve(learning_curve, np.ones(window_size)/window_size, mode='valid')
        line1.set_data(range(num_points), learning_curve)
        line2.set_data(range(len(smoothed_curve)), smoothed_curve)
        return line1, line2  # Return both lines

# Create the animation
ani = FuncAnimation(fig, update, frames=num_points, repeat=False, blit=True)

# Display the dynamic learning curves
plt.xlabel("Time")
plt.ylabel("Reward")
plt.title("Dynamic Reward and Smoothed Reward")
plt.grid()
plt.show()

def train_agent(env, agent, n_episodes=100):
    all_rewards = []

    for episode in range(n_episodes):
        obs = env.reset()
        done = False
        episode_reward = 0

        while not done:
            action = agent.choose_action(obs)
            new_obs, reward, done, _ = env.step(action)

            agent.store_transition(obs, action, reward, new_obs, done)
            agent.learn()

            obs = new_obs
            episode_reward += reward

        all_rewards.append(episode_reward)
        print(f"Episode {episode + 1}: Reward = {episode_reward}")

    return all_rewards

if __name__ == '__main__':
    env = NSCartPoleV0()  # Ensure NSCartPoleV0 is defined properly with continuous action space
    input_dims = env.observation_space.shape[0]
    n_actions = env.action_space.shape[0]
    max_action = env.action_space.high[0]  # Assuming symmetric action space

    agent = ESCPAgent(input_dims=[input_dims], n_actions=n_actions, lr=0.001, gamma=0.99,
                      tau=0.005, alpha=0.2, batch_size=64, mem_size=1000000, max_action=max_action)

    n_episodes = 500
    all_rewards = train_agent(env, agent, n_episodes)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(all_rewards, label='Original Reward')

    smoothed_rewards = [np.mean(all_rewards[max(0, i-10):i+1]) for i in range(len(all_rewards))]
    plt.plot(smoothed_rewards, color='orange', label='Smoothed Reward')

    plt.xlabel('Time')
    plt.ylabel('Reward')
    plt.title("Dynamic Reward and Smoothed Reward")
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# Number of data points in the learning curve
num_points = 500

# Initialize an empty learning curve with random data for animation
learning_curve_animation = np.random.rand(num_points)

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(14, 8))

# Initialize the plot with four empty curves
line1, = ax.plot([], [], lw=2, color='red', label='Original Reward (SAC)')
line2, = ax.plot([], [], lw=2, color='green', label='Smoothed Reward (SAC) ')
line3, = ax.plot([], [], lw=2, color='blue', label='Original Reward (ESCP)')
line4, = ax.plot([], [], lw=2, color='orange', label='Smoothed Reward (ESCP)')
ax.set_xlim(0, num_points)
ax.set_ylim(0, 50)
ax.legend()  # Add a legend

# Define the window size for the moving average
window_size = 10

# Update function for animation
def update(frame):
    if frame < num_points:
        # Simulate changes in the learning curve with random data
        learning_curve_animation[frame:] += np.random.uniform(-0.1, 0.1)
        # Apply a simple moving average to smooth the curve
        smoothed_curve_animation = np.convolve(learning_curve_animation, np.ones(window_size)/window_size, mode='valid')
        line1.set_data(range(num_points), learning_curve_animation)
        line2.set_data(range(len(smoothed_curve_animation)), smoothed_curve_animation)
        return line1, line2  # Return both lines

# Create the animation
ani = FuncAnimation(fig, update, frames=num_points, repeat=False, blit=True)

# Plotting training rewards
line3.set_data(range(n_episodes), all_rewards)

# Plotting smoothed training rewards
smoothed_rewards_training = [np.mean(all_rewards[max(0, i-10):i+1]) for i in range(len(all_rewards))]
line4.set_data(range(len(smoothed_rewards_training)), smoothed_rewards_training)

# Display the dynamic learning curves and training rewards
plt.xlabel("Time")
plt.ylabel("Reward")
plt.title("Dynamic and Training Reward Comparison")
plt.grid()
plt.show()
